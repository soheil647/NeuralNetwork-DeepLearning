# %%
import matplotlib.pyplot as plt

# %%
def corrections(i, r1, r2, m):
    k = i-r1
    h = i-r2
    j = i+r1+1
    l = i+r2+1
    if k<0:
        k = 0
    if h<0:
        h = 0
    if l>m:
        l = m
    if j>m:
        j = m
    return k, h, j, l

def activation_fn(x):
    if x<0:
        return 0
    elif x>2:
        return 2
    else:
        return x

# %%
x = [0.27, 0.35, 0.44, 0.58, 0.66, 0.77, 0.4, 0.32, 0.20, 0.15, 0.08]
r1 = 1
r2 = 12
c1 = 0.6
c2 = -0.4
t_max = 10

# %%
legend_plt = []
print ('t = 0')
for i in range(len(x)):
    print ('x{} = {}'.format(i, x[i]))
plt.plot(x)
for t in range(t_max): #step 3 step 7 & 8
    x_old = x.copy() #step 6
    plt.plot(x_old)
    print ('t = {}'.format(t+1))
    legend_plt.append(t)
    for i in range(len(x_old)):
        k, h, j, l = corrections(i, r1, r2, len(x_old))
        sum1 = sum((x_old[k:j]))
        left = sum(x_old[h:k])
        right = sum((x_old[j:l]))
        sum2 = left + right
        x[i] = activation_fn((c1*sum1 + c2*sum2)) # step 4 & 5
        print ('x{} = {}'.format(i, x[i]))
plt.legend(legend_plt)
plt.xlabel("Index of X")
plt.ylabel("itiration number")
plt.show()
# Out:
# t = 0
# x0 = 0.27
# x1 = 0.35
# x2 = 0.44
# x3 = 0.58
# x4 = 0.66
# x5 = 0.77
# x6 = 0.4
# x7 = 0.32
# x8 = 0.2
# x9 = 0.15
# x10 = 0.08
# t = 1
# x0 = 0
# x1 = 0
# x2 = 0
# x3 = 0
# x4 = 0.32199999999999973
# x5 = 0.14200000000000002
# x6 = 0
# x7 = 0
# x8 = 0
# x9 = 0
# x10 = 0
# t = 2
# x0 = 0
# x1 = 0
# x2 = 0
# x3 = 0.13639999999999983
# x4 = 0.2783999999999998
# x5 = 0.2783999999999998
# x6 = 0
# x7 = 0
# x8 = 0
# x9 = 0
# x10 = 0
# t = 3
# x0 = 0
# x1 = 0
# x2 = 0
# x3 = 0.13751999999999984
# x4 = 0.4159199999999996
# x5 = 0.2795199999999998
# x6 = 0.0011200000000000376
# x7 = 0
# x8 = 0
# x9 = 0
# x10 = 0
# t = 4
# x0 = 0
# x1 = 0
# x2 = 0
# x3 = 0.21980799999999973
# x4 = 0.49932799999999955
# x5 = 0.3629279999999997
# x6 = 0
# x7 = 0
# x8 = 0
# x9 = 0
# x10 = 0
# t = 5
# x0 = 0
# x1 = 0
# x2 = 0
# x3 = 0.2863103999999997
# x4 = 0.6492383999999994
# x5 = 0.42943039999999966
# x6 = 0
# x7 = 0
# x8 = 0
# x9 = 0
# x10 = 0
# t = 6
# x0 = 0
# x1 = 0
# x2 = 0
# x3 = 0.38955711999999965
# x4 = 0.8189875199999992
# x5 = 0.5326771199999996
# x6 = 0
# x7 = 0
# x8 = 0
# x9 = 0
# x10 = 0
# t = 7
# x0 = 0
# x1 = 0
# x2 = 0
# x3 = 0.5120559359999994
# x4 = 1.044733055999999
# x5 = 0.6551759359999993
# x6 = 0
# x7 = 0
# x8 = 0
# x9 = 0
# x10 = 0
# t = 8
# x0 = 0
# x1 = 0
# x2 = 0
# x3 = 0.6720030207999992
# x4 = 1.3271789567999985
# x5 = 0.8151230207999993
# x6 = 0
# x7 = 0
# x8 = 0
# x9 = 0
# x10 = 0
# t = 9
# x0 = 0
# x1 = 0
# x2 = 0
# x3 = 0.8734599782399988
# x4 = 1.6885829990399983
# x5 = 1.0165799782399991
# x6 = 0
# x7 = 0
# x8 = 0
# x9 = 0
# x10 = 0
# t = 10
# x0 = 0
# x1 = 0
# x2 = 0
# x3 = 1.1305937950719986
# x4 = 2
# x5 = 1.273713795071999
# x6 = 0
# x7 = 0
# x8 = 0
# x9 = 0
# x10 = 0
